# %%
import pandas as pd
import nltk
import numpy as np
from wordcloud import WordCloud, STOPWORDS
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from collections import Counter
from nltk import word_tokenize
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# %%
import pickle

# %%
df = pd.read_csv('train.csv')

# %%
print(df.shape)
df.head()
# Out:
# (38932, 5)
#    User_ID                                        Description  \
# 0  id10326  The room was kind of clean but had a VERY stro...
# 1  id10327  I stayed at the Crown Plaza April -- - April -...
# 2  id10328  I booked this hotel through Hotwire at the low...
# 3  id10329  Stayed here with husband and sons on the way t...
# 4  id10330  My girlfriends and I stayed here to celebrate ...
#
#         Browser_Used Device_Used Is_Response
# 0               Edge      Mobile   not happy
# 1  Internet Explorer      Mobile   not happy
# 2            Mozilla      Tablet   not happy
# 3   InternetExplorer     Desktop       happy
# 4               Edge      Tablet   not happy

# %%
print(df['Is_Response'].nunique())
mood_count = df['Is_Response'].value_counts()
mood_count
# Out:
# 2
# happy        26521
# not happy    12411
# Name: Is_Response, dtype: int64

# %%
print(df['Device_Used'].value_counts())
print(df['Browser_Used'].value_counts())
# Out:
# Desktop    15026
# Mobile     14976
# Tablet      8930
# Name: Device_Used, dtype: int64
# Firefox              7367
# Edge                 7134
# Google Chrome        4659
# InternetExplorer     4588
# Mozilla Firefox      4328
# Mozilla              3092
# Chrome               2470
# IE                   2439
# Internet Explorer    2103
# Safari                390
# Opera                 362
# Name: Browser_Used, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
index = [1,2]
plt.bar(index,mood_count)
plt.xticks(index,['happy','not_happy'])
plt.ylabel('Sentiment Count')

# %%
stops = set(STOPWORDS)

# %% [markdown]
# ## Negative response analysis

# %%
dummy_neg = df[df['Is_Response'] == 'not happy']

# %%
words = ' '.join(dummy_neg['Description'])

# %%
b_words = len(words)
b_words
# Out:
# 12927374

# %%
words = ' '.join(word for word in words.split(' ') if word not in stops)

# %%
a_words = len(words)
a_words
# Out:
# 8843945

# %%
print("Ratio of words after and before removal of stopwords {}".format(a_words/b_words))
# Out:
# Ratio of words after and before removal of stopwords 0.6841254070625635

# %%
print("Negative Response WordClould")
wordcloud = WordCloud(stopwords = STOPWORDS, background_color = 'black',height = 2500, width = 3000).generate(words)
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 2999.5, 2499.5, -0.5)

# %% [markdown]
# ## Positive Response analysis

# %%
dummy_pos = df[df['Is_Response'] == 'happy']

# %%
words = ' '.join(dummy_pos['Description'])

# %%
b_words = len(words)

# %%
words = ' '.join(word for word in words.split(' ') if word not in stops)

# %%
a_words = len(words)

# %%
print("Ratio of words after and before removal of stopwords {}".format(a_words/b_words))
# Out:
# Ratio of words after and before removal of stopwords 0.7029443455412356

# %%
print("Positive Response WordClould")
wordcloud = WordCloud(stopwords = STOPWORDS, background_color = 'black',height = 2500, width = 3000).generate(words)
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# Positive Response WordClould
# (-0.5, 2999.5, 2499.5, -0.5)

# %% [markdown]
# ### Both wordclouds have few words in common like 'hotel, room, one, desk, front). So one approach could be removing these words to train the data

# %%
def draw_WordCloud(df,column,stops):
    words = ' '.join(df[column])
    b_words = len(words)
    words = ' '.join(word for word in words.split(' ') if word not in stops)
    a_words = len(words)
    print("Ratio of words after and before removal of stopwords {}".format(a_words/b_words))
    wordcloud = WordCloud(stopwords = STOPWORDS, background_color = 'black',height = 2500, width = 3000).generate(words)
    plt.imshow(wordcloud)
    plt.axis('off')
    return

# %%
draw_WordCloud(dummy_neg,'Description',stops)

# %%
df['sentiment']  = df['Is_Response'].apply(
lambda x : 0 if x == 'not happy' else 1)

# %%
df['sentiment'].value_counts()
# Out:
# 1    26521
# 0    12411
# Name: sentiment, dtype: int64

# %%
count_vec = CountVectorizer(analyzer = "word")
count_vec_ngrams = CountVectorizer(analyzer = "word", ngram_range = (1,2))

# %%
inputDF = df['Description']
outputDF = df['sentiment']

# %%
#inputDF,outputDF = shuffle(inputDF,outputDF,random_state = 42)
#inputDF.reset_index(drop = True,inplace = True)
#outputDF.reset_index(drop=True,inplace = True)

# %% [markdown]
# ## Approach 2 : TF1, making a stoplist of only terms having singleton frequency!

# %%
words = ' '.join(df['Description'])
list_words = word_tokenize(words)

# %%
counts = Counter(list_words)

# %%
stoplist = counts.most_common()[::-1]   #in reverse order

# %%
_stoplist = []
for word, freq in stoplist:
    if(freq>1):
        break
    else:
        _stoplist.append(word)

# %%
len(_stoplist)
# Out:
# 42364

# %%
def clean(data,stoplist):
    list_words = word_tokenize(data)
    words = ' '.join(word for word in list_words if word not in stoplist)
    return words

# %%
inputDF = [clean(inputDF.iloc[i,],_stoplist) for i in range(inputDF.shape[0])]

# %%
words = ' '.join(inputDF)
# Out:
# ["The room was kind of clean but had a VERY strong smell of dogs . Generally below average but ok for a overnight stay if you 're not too fussy . Would consider staying again if the price was right . Breakfast was free and just about better than nothing .",
# ...

# %%
with open('TF1_cleaned_input.p','wb') as fo:
    pickle.dump(inputDF,fo)

# %%
x_train,x_test,y_train,y_test = train_test_split(inputDF,outputDF,random_state=42)

# %% [markdown]
# from nltk.corpus import stopwords
# stops = set(stopwords.words('english'))
# stops.update(':',',','!','.','" "',"' '")

# %%
count_vec = CountVectorizer(analyzer = "word")
count_vec_ngrams = CountVectorizer(analyzer = "word", ngram_range = (1,2))

# %%
train_features = count_vec.fit_transform(x_train)
train_features_grams = count_vec_ngrams.fit_transform(x_train)

# %%
test_features = count_vec.transform(x_test)
test_features_grams = count_vec_ngrams.transform(x_test)

# %% [markdown]
# ## Decision Tree

# %%
clf = DecisionTreeClassifier()
clf_grams = DecisionTreeClassifier()
clf.fit(train_features,y_train)
clf_grams.fit(train_features_grams,y_train)
print(clf_grams.score(test_features_grams,y_test))
print(clf.score(test_features,y_test))
# Out:
# 0.756087537244
# 0.747970820919

# %% [markdown]
# ## MultinomialNB

# %%
clf = MultinomialNB()
clf_grams = MultinomialNB()
clf_grams.fit(train_features_grams,y_train)
clf.fit(train_features,y_train)
print(clf_grams.score(test_features_grams,y_test))
clf.score(test_features,y_test)
# Out:
# 0.870440768519
# 0.86098839001335659

# %%
TF = TfidfVectorizer()
train_features = TF.fit_transform(x_train)
test_features = TF.transform(x_test)

# %%
clf = DecisionTreeClassifier()
clf.fit(train_features,y_train)
clf.score(test_features,y_test)
# Out:
# 0.74190896948525631

# %%
clf = MultinomialNB()
clf.fit(train_features,y_train)
clf.score(test_features,y_test)
# Out:
# 0.82862426795438204

# %% [markdown]
# # MultinomialNB is proved to be better than Decision Tree!
# ### TFidVectorizer is performing better for this Approach, without including standard stoplist!

# %%
words = ' '.join(df['Description'])

# %%
len(words)
# Out:
# 33764807

# %%
words = ' '.join(word for word in words.split(' ') if word not in stops)

# %%
len(words)
# Out:
# 23987643

# %%
list_words = word_tokenize(words)

# %%
words[-100:]
# Out:
# 'ess. The Westin wonderfully restored grande dame hotel. The beds linens excellent. Have pay internet'

# %%
list_words[-100:]
# Out:
# ['busy',
#  'rudely',
#  'told',
#  'us',
#  'would',
#  'go',
#  'get',
#  'mumbling',
#  'us',
#  'left-very',
#  'bad',
#  'customer',
#  'service-given',
#  'mistake',
#  '.',
#  'I',
#  'would',
#  'stay',
#  'again',
#  '.',
#  'The',
#  'experience',
#  'ok.',
#  'We',
#  'paid',
#  'extra',
#  'view',
#  'pool',
#  ',',
#  'got',
#  'view',
#  'palm',
#  'tree',
#  'blocking',
#  'pool',
#  '.',
#  'oh',
#  'well',
#  '...',
#  'better',
#  'parking',
#  'lot',
#  'dumpster',
#  '.',
#  'The',
#  'memorable',
#  'part',
#  'stay',
#  'vent',
#  'shower',
#  'portal',
#  'adjacent',
#  'rooms',
#  '.',
#  'We',
#  'heard',
#  'conversations',
#  'neighbors',
#  'odor',
#  'whatever',
#  'weed',
#  'smoking',
#  'next',
#  'door',
#  'started',
#  'fill',
#  'room',
#  '.',
#  'At',
#  'end',
#  'day',
#  ',',
#  'sure',
#  'staying',
#  'next',
#  'cheech',
#  'chong',
#  '.',
#  'Welcome',
#  'California',
#  ',',
#  'I',
#  'guess',
#  '.',
#  'The',
#  'Westin',
# ...

# %%
counts = Counter(list_words)

# %%
counts
# Out:
# Counter({'The': 78953,
#          'room': 59022,
#          'kind': 1714,
#          'clean': 15342,
#          'VERY': 681,
#          'strong': 264,
#          'smell': 1113,
#          'dogs': 260,
#          '.': 351124,
#          'Generally': 54,
#          'average': 1424,
#          'ok': 1212,
#          'overnight': 584,
#          'stay': 25980,
#          'you': 4759,
#          "'re": 2577,
#          'fussy': 67,
#          'Would': 1536,
#          'consider': 645,
#          'staying': 4466,
#          'price': 6132,
#          'right': 6551,
#          'Breakfast': 1731,
#          'free': 7991,
#          'better': 4734,
#          'nothing': 2517,
#          'I': 108745,
#          'stayed': 14726,
#          'Crown': 69,
#          'Plaza': 721,
#          'April': 311,
#          '--': 53615,
#          '-': 52341,
#          ',': 231523,
#          'staff': 22406,
#          'friendly': 10296,
#          'attentive': 830,
#          'elevators': 1601,
# ...

# %%
counts.most_common(20)
# Out:
# [("''", 557488),
#  ('.', 351124),
#  (',', 231523),
#  ('I', 108745),
#  ('The', 78953),
#  ('hotel', 65861),
#  ('room', 59022),
#  ('--', 53615),
#  ('-', 52341),
#  ('!', 38512),
#  ('We', 33955),
#  (')', 30224),
#  ('(', 29083),
#  ("n't", 26635),
#  ('stay', 25980),
#  ('staff', 22406),
#  ('great', 22230),
#  ('would', 22026),
#  ("'s", 19639),
#  ('rooms', 18262)]

# %% [markdown]
# # We will use counter to eliminate common high frequency words!
# ## Can use a set of positive and negative words set for the training process!

# %%
inputDF = df['Description']
outputDF = df['sentiment']

# %%
stops = set(STOPWORDS)

# %%
stops.update('.','.',':','I','The',')','(','We','-','--','hotel','room','rooms')

# %%
def clean(data):
    #list_words = word_tokenize(data)
    words = data
    words = ' '.join(word for word in list_words if word not in stops)
    return words

# %%
inputDF[0]
# Out:
# "The room was kind of clean but had a VERY strong smell of dogs. Generally below average but ok for a overnight stay if you're not too fussy. Would consider staying again if the price was right. Breakfast was free and just about better than nothing."

# %%
print(clean(inputDF[0]))
# Out:
# was of but had a of . below but for a if you not too . again if the was . was and just about than .

# %%
inputDF = [clean(inputDF.iloc[i,]) for i in range(inputDF.shape[0])]

# %%
len(inputDF)
# Out:
# 38932

# %%
df['Description'][0]
# Out:
# "The room was kind of clean but had a VERY strong smell of dogs. Generally below average but ok for a overnight stay if you're not too fussy. Would consider staying again if the price was right. Breakfast was free and just about better than nothing."

# %%
inputDF[0]
# Out:
# 'was of but had a of . below but for a if you not too . again if the was . was and just about than .'

# %% [markdown]
# # Approach 2 submissions!

# %%
count_vec = CountVectorizer(analyzer = "word")
count_vec_ngrams = CountVectorizer(analyzer = "word", ngram_range = (1,2))
train_features = count_vec.fit_transform(inputDF)
train_features_grams = count_vec_ngrams.fit_transform(inputDF)

# %%
y_train = df['sentiment']

# %%
clf = MultinomialNB()
clf_grams = MultinomialNB()
clf_grams.fit(train_features_grams,y_train)
clf.fit(train_features,y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
testDF = pd.read_csv('test.csv')

# %%
testDF.shape
# Out:
# (29404, 4)

# %%
testing_df = testDF['Description']

# %%
def clean_test(data):
    word_list = word_tokenize(data)
    words = ' '.join(word for word in word_list)
    return words

# %%
_testing_df = [clean_test(testing_df.iloc[i,]) for i in range(testing_df.shape[0])]

# %%
len(' '.join(_testing_df))/len(' '.join(testing_df))
# Out:
# 1.0572374676104266

# %%
len(_testing_df)
# Out:
# 29404

# %% [markdown]
# ## Tokenizing increases word count of the data !

# %%
test_features = count_vec.transform(_testing_df)
test_features_grams = count_vec_ngrams.transform(_testing_df)

# %%
prediction = clf.predict(test_features)
#prediction_grams = clf.predict(test_features_grams)

# %%
testDF['Is_Response'] = prediction

# %%
testDF['Is_Response'] = testDF['Is_Response'].apply(lambda x:'not_happy' if x==0 else 'happy')

# %%
submissionDF = testDF[['User_ID','Is_Response']]

# %%
submissionDF.to_csv('submissions/submission_2.csv',columns=['User_ID','Is_Response'],index=False)

# %% [markdown]
# ## 86.363 accuracy for using MultinomialNB only with TF1 stoplist on hackearth!

# %% [markdown]
# ## Trying TFIDF model too!

# %%
TF = TfidfVectorizer()
train_features = TF.fit_transform(inputDF)
test_features = TF.transform(_testing_df)

# %%
y_train = df['sentiment']

# %%
clf = MultinomialNB()
clf_grams = MultinomialNB()
clf_grams.fit(train_features_grams,y_train)
clf.fit(train_features,y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
prediction = clf.predict(test_features)
#prediction_grams = clf.predict(test_features_grams)

# %%
testDF['Is_Response'] = prediction
testDF['Is_Response'] = testDF['Is_Response'].apply(lambda x:'not_happy' if x==0 else 'happy') 
submissionDF = testDF[['User_ID','Is_Response']]
submissionDF.to_csv('submissions/submission_2_2.csv',columns=['User_ID','Is_Response'],index=False)

# %% [markdown]
# ## 84.070 accuracy on hackerearth for TFIDF !

# %% [markdown]
# ## Now also trying TF HIGH as stop list!

# %%
counts.most_common()[:][::][:][1]
# Out:
# ('.', 352328)

# %%
def plt_count_freq(counts,title=None,_ylim=100000):
    freq = list(set(counts.values()))
    freq.sort()
    freq.reverse()
    plt.plot(freq)
    plt.xlabel('Terms')
    plt.ylabel('freq count')
    plt.ylim(0,_ylim)
    if(title!=None):
        plt.title(title)
    plt.show()

# %%
plt_count_freq(counts,'Corpus')

# %%
neg_words = ' '.join(dummy_neg['Description'])
pos_words = ' '.join(dummy_pos['Description'])

# %%
neg_words_list = word_tokenize(neg_words)
pos_words_list = word_tokenize(pos_words)

# %%
neg_counts = Counter(neg_words_list)
pos_counts = Counter(pos_words_list)

# %%
neg_most_common = neg_counts.most_common()
pos_most_common = pos_counts.most_common()

# %%
tf_high_stoplist = []

# %%
plt_count_freq(pos_counts,'Positive words',40000)
plt_count_freq(neg_counts,'Negative Words',20000)

# %% [markdown]
# ### both have set of words whose frequencies higher than 20,000, so making a stoplist of those common keys, terms!

# %%
pos_most_common[20][1]
# Out:
# 30290

# %%
def create_tf_high_stoplist(pos_counts,neg_counts,thresh=20000):
    pos_words_thresh = []
    stoplist = []
    for word,freq in pos_counts.most_common():
        if freq>=thresh:
            pos_words_thresh.append(word)
        else:
            break
    for word,freq in neg_counts.most_common():
        if(freq<thresh):
            break
        elif(word in pos_words_thresh):
            stoplist.append(word)
    return stoplist

# %%
tf_high_stoplist = create_tf_high_stoplist(pos_counts,neg_counts,7500)

# %%
tf_high_stoplist
# Out:
# ["''",
#  '.',
#  'the',
#  ',',
#  'and',
#  'to',
#  'a',
#  'was',
#  'I',
#  'in',
#  'of',
#  'for',
#  'The',
#  'is',
#  'room',
#  'it',
#  'hotel',
#  '--',
#  'that',
#  '-',
#  'we',
#  'not',
#  'were',
#  'at',
#  'on',
#  'but',
#  'had',
#  'you',
#  'with',
#  'this',
#  "n't",
#  'have',
#  '!',
#  'my',
#  'they',
#  'are',
#  ')',
#  'there',
#  'very',
#  '(',
#  'We',
#  'our',
#  'be',
#  'would',
#  'as',
#  'from',
#  'so',
#  'stay',
#  'did']

# %%
count_vec = CountVectorizer(stop_words = tf_high_stoplist,analyzer='word')

# %%
train_features = count_vec.fit_transform(inputDF)

# %%
test_features = count_vec.transform(_testing_df)

# %%
y_train = df['sentiment']
clf = MultinomialNB()
clf_grams = MultinomialNB()
clf_grams.fit(train_features_grams,y_train)
clf.fit(train_features,y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
prediction = clf.predict(test_features)

# %%
testDF['Is_Response'] = prediction
testDF['Is_Response'] = testDF['Is_Response'].apply(lambda x:'not_happy' if x==0 else 'happy') 
submissionDF = testDF[['User_ID','Is_Response']]
submissionDF.to_csv('submissions/submission_3_1.csv',columns=['User_ID','Is_Response'],index=False)

# %% [markdown]
# # 3rd approach using tf_high stoplist in addition to tf1 resulted in 86.3% accuracy.

# %% [markdown]
# # Now using only tf_high and standard stoplist and TF1!

# %%
stops = set(STOPWORDS)
stops.update(tf_high_stoplist)

# %%
len(set(STOPWORDS))
# Out:
# 186

# %%
count_vec = CountVectorizer(stop_words = stops ,analyzer='word')

# %%
train_features = count_vec.fit_transform(inputDF)
test_features = count_vec.transform(_testing_df)

# %%
y_train = df['sentiment']
clf = MultinomialNB()
clf.fit(train_features,y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
prediction = clf.predict(test_features)

# %%
testDF['Is_Response'] = prediction
testDF['Is_Response'] = testDF['Is_Response'].apply(lambda x:'not_happy' if x==0 else 'happy') 
submissionDF = testDF[['User_ID','Is_Response']]
submissionDF.to_csv('submissions/submission_3_2.csv',columns=['User_ID','Is_Response'],index=False)

# %% [markdown]
# # 86.630% on including all the stopwords: standard, tf1, and tf-high!
# ## Till now only tested on MultinomialNB, to be tried on MaxEntropy!
